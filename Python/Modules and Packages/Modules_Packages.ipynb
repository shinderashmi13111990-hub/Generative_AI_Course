# %% [markdown]
# # Modules and Packages

# %% [markdown]
# ### Modules and Packages are the primary tools used to organize code into reusable, structured, and maintainable components

# %% [markdown]
# ## Module: A single Python file (.py) containing code (variables, functions, classes) that you can import.

# %% [markdown]
# #### Numpy --> NumPy (Numerical Python) is the foundational open-source package for scientific computing in Python. It introduces a powerful, high-performance N-dimensional array object (ndarray) and comprehensive tools for working with them.

# %% [markdown]
# ### Pandas --> Pandas Module can be used when we are going to work with the dataset for cleaning, pre processing, EDA steps, analysis with plotting the graph

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
math.factorial(10)
# Out:
# 3628800

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.3 MB 1.7 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/12.3 MB 1.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.8/12.3 MB 1.9 MB/s eta 0:00:06
#    ------- -------------------------------- 2.4/12.3 MB 2.1 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.3 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/12.3 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.2/12.3 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.5/12.3 MB 2.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/12.3 MB 3.0 MB/s eta 0:00:02
# ...

# %%
import numpy as np
list1 = [1, 2, 3, 4, 5]
numpy_array = np.array(list1)
print(type(numpy_array))
print(numpy_array)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4 5]

# %% [markdown]
# ## Package: A directory (folder) containing multiple modules and a special initialization file

# %% [markdown]
# ### I m trying to create my own library or module and in this library. I want to create functions and attributes in this module

# %%
## __init__.py is a file should be inside the folder to make it a package. 
# It can be empty or can have some code. 
# It is used to initialize the package.

# %%
from package_folder.mathematics import *
addition(10, 20)
# Out:
# 'Cannot divide by zero'

# %%
division(20, 0)
# Out:
# 'Cannot divide by zero'

# %%
from package_folder.subpackage.sum import addition
addition(10, 20, 30)
# Out:
# 60
