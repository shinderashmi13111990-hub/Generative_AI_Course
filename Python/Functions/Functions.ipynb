# %% [markdown]
# # Functions

# %% [markdown]
# ### It offers below benefits
# #### 1. Code Redundancy
# #### 2. Code Reusability
# #### 3. Code Readability

# %%
# Function to check if a given number is even or odd
def even_or_odd():
    number = input("Enter a number: ")
    
    if type(number) != int:
        print("Invalid input. Please enter an integer.")
        return
    elif number % 2 == 0:
        print(f"{number} is even.")
    else:
        print(f"{number} is odd.")
        
# Call the function to check even or odd
even_or_odd()
# Out:
# Invalid input. Please enter an integer.

# %% [markdown]
# ## Difference between parameters and arguments
# #### * Parameters are the inputs that are defined in the function defination
# #### * Arguments are the inputs that are passed while calling the fumction
