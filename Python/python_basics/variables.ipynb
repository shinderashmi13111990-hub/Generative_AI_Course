# %% [markdown]
# # Variables

# %%
age = 23
Name = "Amit"
Height = 5.8
is_true = True

# %%
age
# Out:
# 23

# %%
Name
# Out:
# 'Amit'

# %%
age
Name
# Out:
# 'Amit'

# %%
print(age)
print(Name)
print(Height)
print(is_true)
# Out:
# 23
# Amit
# 5.8
# True

# %%
print(age); print(Name)
# Out:
# 23
# Amit

# %%
print("Name is: ",Name)
# Out:
# Name is:  Amit

# %% [markdown]
# ## Interpreter --> executes the code line by line , like in Python
# ## Compiler --> executes the code completely, like in C

# %%
# Hello I m writing a comment here

# %%
''' Hello
Amit '''
# Out:
# ' Hello\nAmit '

# %% [markdown]
# ## Variable name must start with alphabel or underscore

# %% [markdown]
# ## Variable can contain alphabets, numbers and underscores

# %% [markdown]
# ## Variable are case sensitive

# %% [markdown]
# # Type function

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age=str(age)
print(age)
print(type(age))
# Out:
# 23
# <class 'str'>

# %%
Name="Amit"
Name=int(Name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 Name="Amit"
# ----> 2 Name=int(Name)
#
# ValueError: invalid literal for int() with base 10: 'Amit'

# %% [markdown]
# '''

# %% [markdown]
# ### Every Type casting is not possible
# ### int ---> str

# %% [markdown]
# # input()
# ## input() can take the input from user side and then can store that input into a variable

# %%
Name = input("Enter your name")
print(Name)
# Out:
# p

# %%
Age=int(input("Enter your age"))
print(type(Age))
# Out:
# <class 'int'>

# %%
Age=float(input("Enter your age"))
print(type(Age))
# Out:
# <class 'float'>

# %%
Age
# Out:
# 23.0

# %%
Value=bool(input("Enter a value:"))
print(type(Value))
print(Value)
# Out:
# <class 'bool'>
# True

# %%
# Building a Simple Calculator

value_1=int(input("Enter your first value"))
value_2=int(input("Enter your second value"))
print("The addition for the values is :",value_1+value_2)
print("The subtraction for the values is :",value_1-value_2)
print("The product for the values is :",value_1*value_2)
print("The division for the values is :",value_1/value_2)
# Out:
# The addition for the values is : 20
# The subtraction for the values is : 10
# The product for the values is : 75
# The division for the values is : 3.0
