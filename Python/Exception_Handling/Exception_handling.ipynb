# %% [markdown]
# # Exception Handling

# %%
num1=24
num2=0
print(num1/num2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 num1=24
#       2 num2=0
# ----> 3 print(num1/num2)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Exception handling in Python is a mechanism to handle runtime errors, preventing your program from crashing when something unexpected happens.
